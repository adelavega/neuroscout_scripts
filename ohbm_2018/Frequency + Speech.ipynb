# %%
# %matplotlib inline
import nilearn.plotting as niplt
import nibabel as nib
from pathlib import Path
import pandas as pd

# %%
root = Path('D:/neuroscout/datasets/')

# %%
paths =['SherlockMerlin/derivatives/neuroscout/Jva/fitlins/',
        'HealthyMindNetwork/derivatives/neuroscout/DEb/fitlins',
        'life/derivatives/neuroscout/blB/fitlins']
paths = [root / p for p in paths]

# %%
contrasts = ['speech','subtlexusfrequencyLg10Wf']

# %%
for c in contrasts:
    for p in paths:
        img = list(p.glob('*{}*stat*'.format(c)))
        dset = p.parts[3]
        if img:
            t = 2.58
            print(dset + '_' + c)
            pl = niplt.plot_stat_map(img[0].as_posix(),threshold=t, display_mode='z',
                                    cut_coords=[5])
# Out:
# SherlockMerlin_speech
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\artist.py:879: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)
# HealthyMindNetwork_speech
# life_speech
# SherlockMerlin_subtlexusfrequencyLg10Wf
# HealthyMindNetwork_subtlexusfrequencyLg10Wf
# life_subtlexusfrequencyLg10Wf
