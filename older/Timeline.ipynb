# %%
import pandas as pd
from IPython.display import display, HTML

# %%
run1 = pd.read_table('D:/neuroscout/analyses/wd/first_level/_subject_id_01/fx_getter/sub-01_ses-movie_task-movie_run-1_events_fx.tsv')

# %%
run1['onset_min'] = run1.apply(lambda x: divmod(x.onset, 60), axis=1)

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    display(x)
    pd.reset_option('display.max_rows')

# %%
print_full(run1.pivot(index='onset_min', columns='trial_type', values='amplitude'))
# Out:
# trial_type                   maxfaceArea  maxfaceConfidence  numFaces
# onset_min
# (0.0, 0.12)                          0.0           0.000000       0.0
# (0.0, 0.6)                           0.0           0.000000       0.0
# (0.0, 1.08)                          0.0           0.000000       0.0
# (0.0, 1.56)                          0.0           0.000000       0.0
# (0.0, 2.04)                          0.0           0.000000       0.0
# (0.0, 2.52)                          0.0           0.000000       0.0
# (0.0, 3.0)                           0.0           0.000000       0.0
# (0.0, 3.48)                          0.0           0.000000       0.0
# (0.0, 3.96)                          0.0           0.000000       0.0
# (0.0, 4.44)                          0.0           0.000000       0.0
# (0.0, 4.92)                          0.0           0.000000       0.0
# (0.0, 5.4)                           0.0           0.000000       0.0
# ...
